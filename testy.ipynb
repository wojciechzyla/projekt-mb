# %%
import pm4py

log_path = "logs/running-example.jsonocel"
ocel = pm4py.read_ocel_json(log_path)

# %%
ocel.relations[ocel.relations["ocel:eid"]=="6.0"]
# Out:
#    ocel:eid ocel:activity      ocel:timestamp       ocel:oid  ocel:type  \
# 38      6.0   place order 2019-05-20 12:30:30      iPhone 11   products
# 39      6.0   place order 2019-05-20 12:30:30  iPhone 11 Pro   products
# 40      6.0   place order 2019-05-20 12:30:30       iPad Air   products
# 41      6.0   place order 2019-05-20 12:30:30         990003     orders
# 42      6.0   place order 2019-05-20 12:30:30         880009      items
# 43      6.0   place order 2019-05-20 12:30:30   Majid Rafiei  customers
# 44      6.0   place order 2019-05-20 12:30:30         880010      items
# 45      6.0   place order 2019-05-20 12:30:30     Fire Stick   products
# 46      6.0   place order 2019-05-20 12:30:30         880011      items
# 47      6.0   place order 2019-05-20 12:30:30         880012      items
#
#    ocel:qualifier
# 38           None
# 39           None
# 40           None
# 41           None
# 42           None
# 43           None
# 44           None
# 45           None
# ...

# %%
pm4py.ocel_objects_summary(ocel)
# Out:
#             ocel:oid                               activities_lifecycle  \
# 0             660001  [create package, send package, failed delivery...
# 1             660002  [create package, send package, package delivered]
# 2             660003  [create package, send package, failed delivery...
# 3             660004  [create package, send package, package delivered]
# 4             660005  [create package, send package, package delivered]
# ...              ...                                                ...
# 11516      iPad mini  [place order, place order, confirm order, pick...
# 11517      iPhone 11  [place order, confirm order, pick item, pay or...
# 11518  iPhone 11 Pro  [place order, confirm order, pay order, pick i...
# 11519       iPhone 8  [place order, confirm order, place order, plac...
# 11520       iPhone X  [place order, pick item, place order, confirm ...
#
#           lifecycle_start       lifecycle_end  lifecycle_duration  \
# ...

# %%
result = pm4py.ocel.cluster_equivalent_ocel(ocel, "customers")
# Out:
# /Users/wojciechzyla/Desktop/AGH/semestr_8/MB/projekt-mb/env_mb/lib/python3.8/site-packages/pm4py/objects/ocel/util/rename_objs_ot_tim_lex.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ocel.objects[ocel.object_id_column] = ocel.objects[ocel.object_id_column].map(overall_objects)
# /Users/wojciechzyla/Desktop/AGH/semestr_8/MB/projekt-mb/env_mb/lib/python3.8/site-packages/pm4py/objects/ocel/util/rename_objs_ot_tim_lex.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
ocel.objects["ocel:type"].unique()
# Out:
# array(['products', 'customers', 'items', 'orders', 'packages'],
#       dtype=object)

# %%
ocel.objects[ocel.objects["ocel:type"] == "customers"]
# Out:
#                        ocel:oid  ocel:type  cost producer   age  bankaccount
# 20               Marco Pegoraro  customers   NaN      NaN  50.0      91248.0
# 21                  Gyunam Park  customers   NaN      NaN  55.0      27275.0
# 22                 Majid Rafiei  customers   NaN      NaN  46.0      74370.0
# 23                 Junxiong Gao  customers   NaN      NaN  52.0      96270.0
# 24                  Seran Uysal  customers   NaN      NaN  40.0      69940.0
# 25         Christina Rensinghof  customers   NaN      NaN  41.0      17020.0
# 26            Wil van der Aalst  customers   NaN      NaN  34.0      48846.0
# 27            Christine Dobbert  customers   NaN      NaN  43.0      59702.0
# 28                  Luis Santos  customers   NaN      NaN  48.0      37644.0
# 29                  Kefang Ding  customers   NaN      NaN  38.0      76896.0
# 30       Mohammadreza Fani Sani  customers   NaN      NaN  51.0      61801.0
# ...

# %%
ocel = pm4py.filtering.filter_ocel_object_attribute(ocel, "ocel:oid", ["Majid Rafiei"])
ocel = pm4py.filtering.filter_ocel_event_attribute(ocel, "ocel:activity", ["place order"])

# %%
ocel.relations[ocel.relations["ocel:eid"]=="6.0"]
# Out:
#    ocel:eid ocel:activity      ocel:timestamp      ocel:oid  ocel:type  \
# 43      6.0   place order 2019-05-20 12:30:30  Majid Rafiei  customers
#
#    ocel:qualifier
# 43           None

# %%
# Out:
#        ocel:oid                               activities_lifecycle  \
# 0  Majid Rafiei  [place order, place order, place order, place ...
#
#       lifecycle_start       lifecycle_end  lifecycle_duration  \
# 0 2019-05-20 12:30:30 2020-05-13 16:10:31          31030801.0
#
#   interacting_objects
# 0                  {}
